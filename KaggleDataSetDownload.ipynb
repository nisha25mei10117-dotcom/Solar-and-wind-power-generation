# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha25mei10117-dotcom/Solar-and-wind-power-generation/blob/main/KaggleDataSetDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install kaggle
# !pip install kaggle --quiet

# %%
#Upload kaggle.json file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b03f11c7-0800-450c-8734-a0ba1941a733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b03f11c7-0800-450c-8734-a0ba1941a733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Create kaggle dicrectory
# !mkdir ~/.kaggle

# %%
#Copy kaggle.json file
# !cp kaggle.json ~/.kaggle/

# %%
ls -ltr ~/.kaggle
# Out:
# total 4
# -rw------- 1 root root 72 Nov 23 13:55 kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
#List down all the competitions
# !kaggle competitions list
# Out:
# ref                                                                                 deadline             category                reward  teamCount  userHasEntered
# ----------------------------------------------------------------------------------  -------------------  ---------------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3       2026-04-15 23:59:00  Featured         2,207,152 Usd        144           False
# https://www.kaggle.com/competitions/hull-tactical-market-prediction                 2025-12-15 23:59:00  Featured           100,000 Usd       2564           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection            2026-02-13 23:59:00  Research           100,000 Usd        168           False
# https://www.kaggle.com/competitions/google-tunix-hackathon                          2026-01-12 23:59:00  Featured           100,000 Usd         57           False
# ...

# %%
#List down all datasets
# !kaggle datasets list
# Out:
# ref                                                             title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# wardabilal/spotify-global-music-dataset-20092025                Spotify Global Music Dataset (2009–2025)               1289021  2025-11-11 09:43:05.933000           3122         51  1.0
# sadiajavedd/students-academic-performance-dataset               Students_Academic_Performance_Dataset                     8907  2025-10-23 04:16:35.563000           9067        230  1.0
# zahranusrat/salary                                              Salary Insights by Job Role (2024)                      110295  2025-11-11 07:02:27.350000           1255         24  1.0
# ...

# %%
# !kaggle datasets list -s 'solar-and-wind-power-generation new.csv'
# Out:
# ref                                        title                       size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------  --------------------  ----------  --------------------------  -------------  ---------  ---------------
# willianoliveiragibin/solar-and-wind-power  solar and wind power       40533  2024-07-03 22:32:12.770000             48          2  1.0

# %%
# !kaggle datasets download -d 'willianoliveiragibin/solar-and-wind-power'
# Out:
# Dataset URL: https://www.kaggle.com/datasets/willianoliveiragibin/solar-and-wind-power
# License(s): CC0-1.0
# ...
#   0% 0.00/39.6k [00:00<?, ?B/s]
# 100% 39.6k/39.6k [00:00<00:00, 115MB/s]

# %%
# Execute the command to list the contents of the unzipped directory
# !ls -l /content/KaggleDataSetForSolarAndWindPower
# Out:
# total 172
# -rwxrwxrwx 1 root root 172473 Jul  3  2024 'solar-and-wind-power-generation new.csv'

# %%
# !unzip -o /content/solar-and-wind-power.zip -d /content/KaggleDataSetForSolarAndWindPower
# Out:
# Archive:  /content/solar-and-wind-power.zip
#   inflating: /content/KaggleDataSetForSolarAndWindPower/solar-and-wind-power-generation new.csv

# %%
# !chmod 777 /content/KaggleDataSetForSolarAndWindPower/'solar-and-wind-power-generation new.csv'

# %%
import pandas as pd
df = pd.read_csv('../content/KaggleDataSetForSolarAndWindPower/solar-and-wind-power-generation new.csv')
df.head()
# Out:
#               Entity  Year  solar and wind - TWh
# 0               Asia  1965                     0
# 1  Asia Pacific (EI)  1965                     0
# 2           CIS (EI)  1965                     0
# 3             Europe  1965                     0
# 4        Europe (EI)  1965                     0
